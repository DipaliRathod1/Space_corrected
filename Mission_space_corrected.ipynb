# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df=pd.read_csv("../Datasets/Space_Corrected.csv")

# %%
df
# Out:
#       Unnamed: 0.1  Unnamed: 0 Company Name  \
# 0                0           0       SpaceX
# 1                1           1         CASC
# 2                2           2       SpaceX
# 3                3           3    Roscosmos
# 4                4           4          ULA
# ...            ...         ...          ...
# 4319          4319        4319      US Navy
# 4320          4320        4320         AMBA
# 4321          4321        4321      US Navy
# 4322          4322        4322    RVSN USSR
# 4323          4323        4323    RVSN USSR
#
#                                                Location  \
# 0            LC-39A, Kennedy Space Center, Florida, USA
# 1     Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2                         Pad A, Boca Chica, Texas, USA
# 3          Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4              SLC-41, Cape Canaveral AFS, Florida, USA
# ...                                                 ...
# 4319           LC-18A, Cape Canaveral AFS, Florida, USA
# 4320           LC-26A, Cape Canaveral AFS, Florida, USA
# 4321           LC-18A, Cape Canaveral AFS, Florida, USA
# 4322          Site 1/5, Baikonur Cosmodrome, Kazakhstan
# 4323          Site 1/5, Baikonur Cosmodrome, Kazakhstan
#
#                            Datum  \
# 0     Fri Aug 07, 2020 05:12 UTC
# 1     Thu Aug 06, 2020 04:01 UTC
# 2     Tue Aug 04, 2020 23:57 UTC
# 3     Thu Jul 30, 2020 21:25 UTC
# 4     Thu Jul 30, 2020 11:50 UTC
# ...                          ...
# 4319  Wed Feb 05, 1958 07:33 UTC
# 4320  Sat Feb 01, 1958 03:48 UTC
# 4321  Fri Dec 06, 1957 16:44 UTC
# 4322  Sun Nov 03, 1957 02:30 UTC
# 4323  Fri Oct 04, 1957 19:28 UTC
#
#                                             Detail  Status Rocket  Rocket  \
# 0     Falcon 9 Block 5 | Starlink V1 L9 & BlackSky   StatusActive   50.0
# 1              Long March 2D | Gaofen-9 04 & Q-SAT   StatusActive  29.75
# 2               Starship Prototype | 150 Meter Hop   StatusActive     NaN
# 3     Proton-M/Briz-M | Ekspress-80 & Ekspress-103   StatusActive   65.0
# 4                       Atlas V 541 | Perseverance   StatusActive  145.0
# ...                                            ...            ...     ...
# 4319                     Vanguard | Vanguard TV3BU  StatusRetired     NaN
# 4320                           Juno I | Explorer 1  StatusRetired     NaN
# 4321                       Vanguard | Vanguard TV3  StatusRetired     NaN
# 4322                    Sputnik 8K71PS | Sputnik-2  StatusRetired     NaN
# 4323                    Sputnik 8K71PS | Sputnik-1  StatusRetired     NaN
#
#      Status Mission
# 0           Success
# 1           Success
# 2           Success
# 3           Success
# 4           Success
# ...             ...
# 4319        Failure
# 4320        Success
# 4321        Failure
# 4322        Success
# 4323        Success
#
# [4324 rows x 9 columns]

# %%
df.dtypes
# Out:
# Unnamed: 0.1       int64
# Unnamed: 0         int64
# Company Name      object
# Location          object
# Datum             object
# Detail            object
# Status Rocket     object
#  Rocket           object
# Status Mission    object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Unnamed: 0.1         0
# Unnamed: 0           0
# Company Name         0
# Location             0
# Datum                0
# Detail               0
# Status Rocket        0
#  Rocket           3360
# Status Mission       0
# dtype: int64

# %%
df=df.rename(columns={'Detail': 'Rocket'})

# %%
df=df.rename(columns={' Rocket': 'Price'})

# %%
df=df.rename(columns={'Status Rocket':'Status_Rocket'})
df=df.rename(columns={'Company Name':'Company_Name'})
df=df.rename(columns={'Status Mission':'Status_Mission'})

# %%
df
# Out:
#       Unnamed: 0.1  Unnamed: 0 Company_Name  \
# 0                0           0       SpaceX
# 1                1           1         CASC
# 2                2           2       SpaceX
# 3                3           3    Roscosmos
# 4                4           4          ULA
# ...            ...         ...          ...
# 4319          4319        4319      US Navy
# 4320          4320        4320         AMBA
# 4321          4321        4321      US Navy
# 4322          4322        4322    RVSN USSR
# 4323          4323        4323    RVSN USSR
#
#                                                Location  \
# 0            LC-39A, Kennedy Space Center, Florida, USA
# 1     Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2                         Pad A, Boca Chica, Texas, USA
# 3          Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4              SLC-41, Cape Canaveral AFS, Florida, USA
# ...                                                 ...
# 4319           LC-18A, Cape Canaveral AFS, Florida, USA
# 4320           LC-26A, Cape Canaveral AFS, Florida, USA
# 4321           LC-18A, Cape Canaveral AFS, Florida, USA
# 4322          Site 1/5, Baikonur Cosmodrome, Kazakhstan
# 4323          Site 1/5, Baikonur Cosmodrome, Kazakhstan
#
#                            Datum  \
# 0     Fri Aug 07, 2020 05:12 UTC
# 1     Thu Aug 06, 2020 04:01 UTC
# 2     Tue Aug 04, 2020 23:57 UTC
# 3     Thu Jul 30, 2020 21:25 UTC
# 4     Thu Jul 30, 2020 11:50 UTC
# ...                          ...
# 4319  Wed Feb 05, 1958 07:33 UTC
# 4320  Sat Feb 01, 1958 03:48 UTC
# 4321  Fri Dec 06, 1957 16:44 UTC
# 4322  Sun Nov 03, 1957 02:30 UTC
# 4323  Fri Oct 04, 1957 19:28 UTC
#
#                                             Detail  Status_Rocket   Price  \
# 0     Falcon 9 Block 5 | Starlink V1 L9 & BlackSky   StatusActive   50.0
# 1              Long March 2D | Gaofen-9 04 & Q-SAT   StatusActive  29.75
# 2               Starship Prototype | 150 Meter Hop   StatusActive     NaN
# 3     Proton-M/Briz-M | Ekspress-80 & Ekspress-103   StatusActive   65.0
# 4                       Atlas V 541 | Perseverance   StatusActive  145.0
# ...                                            ...            ...     ...
# 4319                     Vanguard | Vanguard TV3BU  StatusRetired     NaN
# 4320                           Juno I | Explorer 1  StatusRetired     NaN
# 4321                       Vanguard | Vanguard TV3  StatusRetired     NaN
# 4322                    Sputnik 8K71PS | Sputnik-2  StatusRetired     NaN
# 4323                    Sputnik 8K71PS | Sputnik-1  StatusRetired     NaN
#
#      Status_Mission
# 0           Success
# 1           Success
# 2           Success
# 3           Success
# 4           Success
# ...             ...
# 4319        Failure
# 4320        Success
# 4321        Failure
# 4322        Success
# 4323        Success
#
# [4324 rows x 9 columns]

# %%
df.Price = df.Price.fillna(0)

# %%
df.Price.unique()
# Out:
# array(['50.0 ', '29.75 ', 0, '65.0 ', '145.0 ', '64.68 ', '48.5 ',
#        '90.0 ', '46.0 ', '28.3 ', '29.15 ', '7.5 ', '30.8 ', '5.3 ',
#        '12.0 ', '112.5 ', '120.0 ', '153.0 ', '200.0 ', '85.0 ', '115.0 ',
#        '41.8 ', '21.0 ', '31.0 ', '40.0 ', '164.0 ', '62.0 ', '37.0 ',
#        '350.0 ', '39.0 ', '47.0 ', '35.0 ', '69.7 ', '109.0 ', '45.0 ',
#        '123.0 ', '130.0 ', '25.0 ', '56.5 ', '15.0 ', '29.0 ', '80.0 ',
#        '140.0 ', '55.0 ', '59.5 ', '450.0 ', '7.0 ', '20.14 ', '133.0 ',
#        '190.0 ', '135.0 ', '20.0 ', '136.6 ', '5,000.0 ', '1,160.0 ',
#        '59.0 ', '63.23 '], dtype=object)

# %%
df.Price = df.Price.replace('[,]','',regex=True).astype('float64')

# %%
df.Datum=df.Datum.astype('datetime64[ns, UTC]')

# %%
df['Year']= df['Datum'].dt.year
df['Month']= df['Datum'].dt.month

# %%
df.dtypes
# Out:
# Unnamed: 0.1                    int64
# Unnamed: 0                      int64
# Company_Name                   object
# Location                       object
# Datum             datetime64[ns, UTC]
# Detail                         object
# Status_Rocket                  object
# Price                         float64
# Status_Mission                 object
# Year                            int32
# Month                           int32
# dtype: object

# %%
df.describe()
# Out:
#        Unnamed: 0.1   Unnamed: 0        Price         Year        Month
# count   4324.000000  4324.000000  4324.000000  4324.000000  4324.000000
# mean    2161.500000  2161.500000    34.286698  1987.386679     6.754163
# std     1248.375611  1248.375611   150.442829    18.072562     3.417027
# min        0.000000     0.000000     0.000000  1957.000000     1.000000
# 25%     1080.750000  1080.750000     0.000000  1972.000000     4.000000
# 50%     2161.500000  2161.500000     0.000000  1984.000000     7.000000
# 75%     3242.250000  3242.250000     0.000000  2002.000000    10.000000
# max     4323.000000  4323.000000  5000.000000  2020.000000    12.000000

# %%
df.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'Company_Name', 'Location', 'Datum',
#        'Detail', 'Status_Rocket', 'Price', 'Status_Mission', 'Year', 'Month'],
#       dtype='object')

# %%
df = df.drop('Unnamed: 0.1',axis=1)

# %%
df
# Out:
#       Unnamed: 0 Company_Name  \
# 0              0       SpaceX
# 1              1         CASC
# 2              2       SpaceX
# 3              3    Roscosmos
# 4              4          ULA
# ...          ...          ...
# 4319        4319      US Navy
# 4320        4320         AMBA
# 4321        4321      US Navy
# 4322        4322    RVSN USSR
# 4323        4323    RVSN USSR
#
#                                                Location  \
# 0            LC-39A, Kennedy Space Center, Florida, USA
# 1     Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2                         Pad A, Boca Chica, Texas, USA
# 3          Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4              SLC-41, Cape Canaveral AFS, Florida, USA
# ...                                                 ...
# 4319           LC-18A, Cape Canaveral AFS, Florida, USA
# 4320           LC-26A, Cape Canaveral AFS, Florida, USA
# 4321           LC-18A, Cape Canaveral AFS, Florida, USA
# 4322          Site 1/5, Baikonur Cosmodrome, Kazakhstan
# 4323          Site 1/5, Baikonur Cosmodrome, Kazakhstan
#
#                          Datum                                        Detail  \
# 0    2020-08-07 05:12:00+00:00  Falcon 9 Block 5 | Starlink V1 L9 & BlackSky
# 1    2020-08-06 04:01:00+00:00           Long March 2D | Gaofen-9 04 & Q-SAT
# 2    2020-08-04 23:57:00+00:00            Starship Prototype | 150 Meter Hop
# 3    2020-07-30 21:25:00+00:00  Proton-M/Briz-M | Ekspress-80 & Ekspress-103
# 4    2020-07-30 11:50:00+00:00                    Atlas V 541 | Perseverance
# ...                        ...                                           ...
# 4319 1958-02-05 07:33:00+00:00                     Vanguard | Vanguard TV3BU
# 4320 1958-02-01 03:48:00+00:00                           Juno I | Explorer 1
# 4321 1957-12-06 16:44:00+00:00                       Vanguard | Vanguard TV3
# 4322 1957-11-03 02:30:00+00:00                    Sputnik 8K71PS | Sputnik-2
# 4323 1957-10-04 19:28:00+00:00                    Sputnik 8K71PS | Sputnik-1
#
#       Status_Rocket   Price Status_Mission  Year  Month
# 0      StatusActive   50.00        Success  2020      8
# 1      StatusActive   29.75        Success  2020      8
# 2      StatusActive    0.00        Success  2020      8
# 3      StatusActive   65.00        Success  2020      7
# 4      StatusActive  145.00        Success  2020      7
# ...             ...     ...            ...   ...    ...
# 4319  StatusRetired    0.00        Failure  1958      2
# 4320  StatusRetired    0.00        Success  1958      2
# 4321  StatusRetired    0.00        Failure  1957     12
# 4322  StatusRetired    0.00        Success  1957     11
# 4323  StatusRetired    0.00        Success  1957     10
#
# [4324 rows x 10 columns]

# %%
df['Company_Name'].value_counts()
# Out:
# Company_Name
# RVSN USSR           1777
# Arianespace          279
# CASC                 251
# General Dynamics     251
# NASA                 203
# VKS RF               201
# US Air Force         161
# ULA                  140
# Boeing               136
# Martin Marietta      114
# SpaceX               100
# MHI                   84
# Northrop              83
# Lockheed              79
# ISRO                  76
# Roscosmos             55
# ILS                   46
# Sea Launch            36
# ISAS                  30
# Kosmotras             22
# US Navy               17
# ISA                   13
# Rocket Lab            13
# Eurockot              13
# ESA                   13
# Blue Origin           12
# IAI                   11
# ExPace                10
# ASI                    9
# CNES                   8
# AMBA                   8
# MITT                   7
# JAXA                   7
# Land Launch            7
# UT                     5
# KCST                   5
# CASIC                  5
# Exos                   4
# CECLES                 4
# Arm??e de l'Air        4
# KARI                   3
# SRC                    3
# AEB                    3
# RAE                    2
# OKB-586                2
# Yuzhmash               2
# Landspace              1
# Douglas                1
# EER                    1
# Starsem                1
# Virgin Orbit           1
# IRGC                   1
# i-Space                1
# OneSpace               1
# Sandia                 1
# Khrunichev             1
# Name: count, dtype: int64

# %%
sb.histplot(x=df.Price)
plt.xticks(rotation=90)
plt.show()

# %%
sb.boxplot(df.Price)
plt.xticks(rotation=90)
plt.show()

# %%
df['Company_Name'].value_counts()
# Out:
# Company_Name
# RVSN USSR           1777
# Arianespace          279
# CASC                 251
# General Dynamics     251
# NASA                 203
# VKS RF               201
# US Air Force         161
# ULA                  140
# Boeing               136
# Martin Marietta      114
# SpaceX               100
# MHI                   84
# Northrop              83
# Lockheed              79
# ISRO                  76
# Roscosmos             55
# ILS                   46
# Sea Launch            36
# ISAS                  30
# Kosmotras             22
# US Navy               17
# ISA                   13
# Rocket Lab            13
# Eurockot              13
# ESA                   13
# Blue Origin           12
# IAI                   11
# ExPace                10
# ASI                    9
# CNES                   8
# AMBA                   8
# MITT                   7
# JAXA                   7
# Land Launch            7
# UT                     5
# KCST                   5
# CASIC                  5
# Exos                   4
# CECLES                 4
# Arm??e de l'Air        4
# KARI                   3
# SRC                    3
# AEB                    3
# RAE                    2
# OKB-586                2
# Yuzhmash               2
# Landspace              1
# Douglas                1
# EER                    1
# Starsem                1
# Virgin Orbit           1
# IRGC                   1
# i-Space                1
# OneSpace               1
# Sandia                 1
# Khrunichev             1
# Name: count, dtype: int64

# %%
df['Company_Name'].value_counts().nlargest(10)
# Out:
# Company_Name
# RVSN USSR           1777
# Arianespace          279
# CASC                 251
# General Dynamics     251
# NASA                 203
# VKS RF               201
# US Air Force         161
# ULA                  140
# Boeing               136
# Martin Marietta      114
# Name: count, dtype: int64

# %%
df[df['Status_Mission']=='Success'].groupby('Company_Name').size().nlargest(20)
# Out:
# Company_Name
# RVSN USSR           1614
# Arianespace          269
# CASC                 231
# General Dynamics     203
# VKS RF               188
# NASA                 186
# ULA                  139
# Boeing               131
# US Air Force         129
# Martin Marietta      100
# SpaceX                94
# MHI                   80
# Lockheed              74
# Northrop              74
# ISRO                  63
# Roscosmos             51
# ILS                   45
# Sea Launch            33
# ISAS                  26
# Kosmotras             21
# dtype: int64

# %%
df['Location'].value_counts()
# Out:
# Location
# Site 31/6, Baikonur Cosmodrome, Kazakhstan               235
# Site 132/1, Plesetsk Cosmodrome, Russia                  216
# Site 43/4, Plesetsk Cosmodrome, Russia                   202
# Site 41/1, Plesetsk Cosmodrome, Russia                   198
# Site 1/5, Baikonur Cosmodrome, Kazakhstan                193
#                                                         ...
# Jiuquan Satellite Launch Center, China                     1
# LP-41, Kauai, Pacific Missile Range Facility               1
# Tai Rui Barge, Yellow Sea                                  1
# Launch Plateform, Shahrud Missile Test Site                1
# K-496 Submarine, Barents Sea Launch Area, Barents Sea      1
# Name: count, Length: 137, dtype: int64

# %%
df[df['Status_Mission']=='Success'].groupby('Location').size().nlargest(20)
# Out:
# Location
# Site 31/6, Baikonur Cosmodrome, Kazakhstan           220
# Site 132/1, Plesetsk Cosmodrome, Russia              203
# Site 43/4, Plesetsk Cosmodrome, Russia               190
# Site 41/1, Plesetsk Cosmodrome, Russia               186
# Site 132/2, Plesetsk Cosmodrome, Russia              164
# Site 1/5, Baikonur Cosmodrome, Kazakhstan            155
# Site 133/3, Plesetsk Cosmodrome, Russia              147
# Site 43/3, Plesetsk Cosmodrome, Russia               131
# LC-39A, Kennedy Space Center, Florida, USA           117
# ELA-2, Guiana Space Centre, French Guiana, France    115
# ELA-3, Guiana Space Centre, French Guiana, France    104
# SLC-40, Cape Canaveral AFS, Florida, USA             101
# SLC-41, Cape Canaveral AFS, Florida, USA              91
# SLC-4W, Vandenberg AFB, California, USA               87
# SLC-4E, Vandenberg AFB, California, USA               78
# SLC-17A, Cape Canaveral AFS, Florida, USA             74
# LA-Y1, Tanegashima Space Center, Japan                69
# Site 90/20, Baikonur Cosmodrome, Kazakhstan           69
# SLC-36B, Cape Canaveral AFS, Florida, USA             68
# Site 86/1, Kapustin Yar, Russia                       62
# dtype: int64

# %%
df['Rocket'].value_counts()
# Out:
# Rocket
# Cosmos-3MRB (65MRB) | BOR-5 Shuttle    6
# Lambda-IV S | Osumi                    5
# Titan IV(402)B | DSP                   5
# Titan IIID | KH-11                     5
# Proton K/Block D | Zond                4
#                                       ..
# Ariane 44P | Intelsat 709              1
# Ariane 5 G | Cluster                   1
# Delta II 7925 | Galaxy 9               1
# Space Shuttle Endeavour | STS-77       1
# Sputnik 8K71PS | Sputnik-1             1
# Name: count, Length: 4278, dtype: int64

# %%
sb.countplot('Price')
plt.xticks(rotation=90)
plt.show()

# %%
df['Status_Rocket'].value_counts()
# Out:
# Status_Rocket
# StatusRetired    3534
# StatusActive      790
# Name: count, dtype: int64

# %%
sb.barplot(x=df.Status_Rocket,y=df.Price)
plt.xticks(rotation=90)
plt.show()

# %%
a=df.groupby('Rocket')['Price'].mean()*100
a
# Out:
# Rocket
# ASLV | SROSS C                   0.0
# ASLV | SROSS C2                  0.0
# ASLV | SROSS-A                   0.0
# ASLV | SROSS-B                   0.0
# Angara 1.2 | Demo Flight         0.0
#                                 ...
# Zenit-3 SLBF | AngoSat-1         0.0
# Zenit-3 SLBF | Elektro-L n†­1    0.0
# Zenit-3 SLBF | Elektro-L n†­2    0.0
# Zenit-3 SLBF | Spektr-R          0.0
# ZhuQue-1 | CCTV Future-1         0.0
# Name: Price, Length: 4278, dtype: float64

# %%
sb.countplot(x=a)
plt.xticks(rotation=90)
plt.show()

# %%
df[['Company_Name','Price']].groupby('Company_Name').mean()
# Out:
#                        Price
# Company_Name
# AEB                 0.000000
# AMBA                0.000000
# ASI                 0.000000
# Arianespace        58.584229
# Arm??e de l'Air     0.000000
# Blue Origin         0.000000
# Boeing              9.125000
# CASC               25.260000
# CASIC               0.000000
# CECLES              0.000000
# CNES                0.000000
# Douglas             0.000000
# EER                20.000000
# ESA                 2.846154
# Eurockot           41.800000
# ExPace              2.830000
# Exos                0.000000
# General Dynamics    0.000000
# IAI                 0.000000
# ILS                28.695652
# IRGC                0.000000
# ISA                 0.000000
# ISAS                0.000000
# ISRO               28.644737
# JAXA               24.000000
# KARI                0.000000
# KCST                0.000000
# Khrunichev          0.000000
# Kosmotras          29.000000
# Land Launch         0.000000
# Landspace           0.000000
# Lockheed            3.544304
# MHI                42.053571
# MITT                0.000000
# Martin Marietta     6.328070
# NASA              375.763547
# Northrop           47.349398
# OKB-586             0.000000
# OneSpace            0.000000
# RAE                 0.000000
# RVSN USSR           5.627462
# Rocket Lab          7.500000
# Roscosmos          21.590909
# SRC                 0.000000
# Sandia             15.000000
# Sea Launch          0.000000
# SpaceX             54.440000
# Starsem             0.000000
# ULA               105.700000
# US Air Force        9.633043
# US Navy             0.000000
# UT                  0.000000
# VKS RF              7.705970
# Virgin Orbit       12.000000
# Yuzhmash            0.000000
# i-Space             0.000000

# %%
df.groupby('Company_Name')['Price'].mean()
# Out:
# Company_Name
# AEB                   0.000000
# AMBA                  0.000000
# ASI                   0.000000
# Arianespace          58.584229
# Arm??e de l'Air       0.000000
# Blue Origin           0.000000
# Boeing                9.125000
# CASC                 25.260000
# CASIC                 0.000000
# CECLES                0.000000
# CNES                  0.000000
# Douglas               0.000000
# EER                  20.000000
# ESA                   2.846154
# Eurockot             41.800000
# ExPace                2.830000
# Exos                  0.000000
# General Dynamics      0.000000
# IAI                   0.000000
# ILS                  28.695652
# IRGC                  0.000000
# ISA                   0.000000
# ISAS                  0.000000
# ISRO                 28.644737
# JAXA                 24.000000
# KARI                  0.000000
# KCST                  0.000000
# Khrunichev            0.000000
# Kosmotras            29.000000
# Land Launch           0.000000
# Landspace             0.000000
# Lockheed              3.544304
# MHI                  42.053571
# MITT                  0.000000
# Martin Marietta       6.328070
# NASA                375.763547
# Northrop             47.349398
# OKB-586               0.000000
# OneSpace              0.000000
# RAE                   0.000000
# RVSN USSR             5.627462
# Rocket Lab            7.500000
# Roscosmos            21.590909
# SRC                   0.000000
# Sandia               15.000000
# Sea Launch            0.000000
# SpaceX               54.440000
# Starsem               0.000000
# ULA                 105.700000
# US Air Force          9.633043
# US Navy               0.000000
# UT                    0.000000
# VKS RF                7.705970
# Virgin Orbit         12.000000
# Yuzhmash              0.000000
# i-Space               0.000000
# Name: Price, dtype: float64

# %%
df[df['Status_Mission'] == 'Success'].groupby('Rocket')['Price'].mean()
# Out:
# Rocket
# ASLV | SROSS C2                    0.0
# Angara 1.2 | Demo Flight           0.0
# Angara A5/Briz-M | Demo Flight     0.0
# Antares 110 | Antares A-ONE       80.0
# Antares 110 | CRS Orb-D1          80.0
#                                   ...
# Zenit-3 SLB | Telstar-11N          0.0
# Zenit-3 SLBF | AngoSat-1           0.0
# Zenit-3 SLBF | Elektro-L n†­1      0.0
# Zenit-3 SLBF | Elektro-L n†­2      0.0
# Zenit-3 SLBF | Spektr-R            0.0
# Name: Price, Length: 3846, dtype: float64

# %%
df['Year'].value_counts().sort_index()
# Out:
# Year
# 1957      3
# 1958     28
# 1959     20
# 1960     39
# 1961     52
#        ...
# 2016     90
# 2017     92
# 2018    117
# 2019    109
# 2020     63
# Name: count, Length: 64, dtype: int64

# %%
sb.lineplot(x=df.Year,y=df.Status_Mission)
plt.xticks(rotation=90)
plt.show()
